# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260501_122048_default\dataset_merged.csv')

# %%
data
# Out:
#      Country  Year   Agri_GDP  Credit_Private  Elec_Access  Emp_Services  \
# 0        ABW  2004   0.017566       51.785230        100.0           NaN
# 1        ABW  2005   0.017328       54.060701        100.0           NaN
# 2        ABW  2006   0.017508       53.884120        100.0           NaN
# 3        ABW  2007   0.017839       51.727256        100.0           NaN
# 4        ABW  2008   0.016997       50.658458        100.0           NaN
# ...      ...   ...        ...             ...          ...           ...
# 5581     ZWE  2020  20.847051        3.642132         52.7     29.065145
# 5582     ZWE  2021  21.485653        4.759522         49.0     32.890243
# 5583     ZWE  2022  17.061231        5.826323         50.1     34.367819
# 5584     ZWE  2023  11.494869        6.477697         62.0     33.158381
# 5585     ZWE  2024   8.688451             NaN          NaN     33.394773
#
#         FDI_GDP     GDPC_2015  Indus_GDP  Internet_Usage   Serv_GDP
# ...

# %%
data = pd.read_csv(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260501_122048_default\dataset_final.csv')

# %%
data
# Out:
#      Country  Year  Agri_GDP  Credit_Private  Elec_Access  Emp_Services  \
# 0        ABW  2004  0.001428        0.609014     1.000000      0.910911
# 1        ABW  2005  0.001373        0.618475     1.000000      0.908247
# 2        ABW  2006  0.001415        0.617755     1.000000      0.908247
# 3        ABW  2007  0.001492        0.608768     1.000000      0.908247
# 4        ABW  2008  0.001295        0.604178     1.000000      0.907468
# ...      ...   ...       ...             ...          ...           ...
# 5581     ZWE  2020  0.732671        0.064079     0.271435      0.308943
# 5582     ZWE  2021  0.739541        0.112425     0.189099      0.381091
# 5583     ZWE  2022  0.687294        0.150516     0.214197      0.406799
# 5584     ZWE  2023  0.599437        0.170945     0.455646      0.385838
# 5585     ZWE  2024  0.538780        0.139279     0.016572      0.389993
#
#        FDI_GDP  GDPC_2015  Indus_GDP  Internet_Usage  Serv_GDP
# ...

# %%
data = pd.read_csv(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260501_122048_default\diagnostic_report.csv')

# %%
data
# Out:
#         Indicator  count  missing_count  missing_percentage  outlier_count  \
# 0            Year   5586              0                0.00              0
# 1        Agri_GDP   5101            485                8.68             59
# 2  Credit_Private   4384           1202               21.52            164
# 3     Elec_Access   5249            337                6.03            358
# 4    Emp_Services   4926            660               11.82              0
# 5         FDI_GDP   5071            515                9.22            560
# 6       GDPC_2015   5355            231                4.14            494
# 7       Indus_GDP   5108            478                8.56            215
# 8  Internet_Usage   4622            964               17.26              0
# 9        Serv_GDP   5076            510                9.13             93
#
#    outlier_percentage        mean     median         std  skewness  kurtosis  \
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Load ảnh (trả về mảng NumPy)
img = cv2.imread(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260422_082638_default_phase0\boxplots.png')

# OpenCV mặc định đọc hệ màu BGR, cần chuyển sang RGB để hiển thị đúng với Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 8)) # Tăng kích thước khung hình
plt.imshow(img_rgb)

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/40.2 MB 508.0 kB/s eta 0:01:19
#     --------------------------------------- 0.5/40.2 MB 508.0 kB/s eta 0:01:19
#     --------------------------------------- 0.8/40.2 MB 479.2 kB/s eta 0:01:23
#     --------------------------------------- 0.8/40.2 MB 479.2 kB/s eta 0:01:23
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Load ảnh (trả về mảng NumPy)
img = cv2.imread(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260422_082638_default_phase0\histograms.png')

# OpenCV mặc định đọc hệ màu BGR, cần chuyển sang RGB để hiển thị đúng với Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 8)) # Tăng kích thước khung hình
plt.imshow(img_rgb)

# %%
import cv2
import matplotlib.pyplot as plt

# Load ảnh (trả về mảng NumPy)
img = cv2.imread(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260422_082638_default_phase0\missing_values_by_year.png')

# OpenCV mặc định đọc hệ màu BGR, cần chuyển sang RGB để hiển thị đúng với Matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 8)) # Tăng kích thước khung hình
plt.imshow(img_rgb)

# %%
import cv2
import matplotlib.pyplot as plt

# Load ảnh Heatmap (trả về mảng NumPy)
img_heatmap = cv2.imread(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260430_030448_default_phase0\correlation_heatmap.png')

# OpenCV mặc định đọc hệ màu BGR, cần chuyển sang RGB
img_heatmap_rgb = cv2.cvtColor(img_heatmap, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(14, 10)) # Tăng kích thước khung hình vì Heatmap cần không gian để đọc số
plt.imshow(img_heatmap_rgb)
plt.axis('off') # Tắt trục tọa độ pixel cho bức ảnh đẹp hơn
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load ảnh Scatter Plot (trả về mảng NumPy)
img_scatter = cv2.imread(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260430_030448_default_phase0\pairwise_scatter.png')

# OpenCV mặc định đọc hệ màu BGR, cần chuyển sang RGB
img_scatter_rgb = cv2.cvtColor(img_scatter, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(16, 12)) # Tăng mạnh kích thước vì Scatter Plot ma trận chứa rất nhiều biểu đồ con
plt.imshow(img_scatter_rgb)
plt.axis('off') 
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load ảnh KDE (trả về mảng NumPy)
img_kde = cv2.imread(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260501_122048_default\kde_before_after_transform.png')

# Chuyển hệ màu BGR sang RGB
img_kde_rgb = cv2.cvtColor(img_kde, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(16, 20)) # Tăng mạnh chiều cao vì biểu đồ này xếp dọc khá dài
plt.imshow(img_kde_rgb)
plt.axis('off') 
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load ảnh Stacked Bar (trả về mảng NumPy)
img_stacked = cv2.imread(r'C:\Users\Admin\Documents\GitHub\WorldBank-Data-Analysis-Project\pipeline_execution\outputs\runs\run_20260430_033453_default_phase1\probability_stacked_bars.png')

# Chuyển hệ màu BGR sang RGB
img_stacked_rgb = cv2.cvtColor(img_stacked, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(16, 10)) # Khung hình chữ nhật nằm ngang
plt.imshow(img_stacked_rgb)
plt.axis('off') 
plt.show()
