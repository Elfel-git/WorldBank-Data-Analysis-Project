# %% [markdown]
# Xử lý giá tị thiếu (missing values)
# Loại bỏ hoặc thay thế outlier
# Chuẩn hóa kiểu dữ liệu
# Loại bỏ trùng lặp

# %% [markdown]
# # Data cleaning

# %%
import pandas as pd

# %%
data = pd.read_csv(r'E:\WorldBank-Data-Analysis-Project\new_data\Access to electricity.csv')

# %%
data.head(5)
# Out:
#   economy      YR2004      YR2005      YR2006      YR2007      YR2008  \
# 0     ABW  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     AFE   23.724455   23.449539   25.172482   26.795145   25.908845
# 2     AFG   23.800000   28.700000   33.500000   38.400000   42.400000
# 3     AFW   37.594502   37.935910   39.952904   40.864862   41.866015
# 4     AGO   28.400000   29.400000   30.500000   37.500000   38.500000
#
#        YR2009     YR2010      YR2011      YR2012  ...      YR2015      YR2016  \
# 0  100.000000  93.400000  100.000000  100.000000  ...  100.000000  100.000000
# 1   26.187846  27.414954   28.909756   31.673427  ...   33.922276   38.859598
# 2   48.300000  42.700000   43.200000   69.100000  ...   71.500000   97.700000
# 3   42.002485  41.951990   46.061967   44.186500  ...   46.862418   51.045127
# 4   33.800000  35.000000   34.600000   37.300000  ...   42.000000   41.800000
#
#        YR2017      YR2018      YR2019      YR2020      YR2021     YR2022  \
# ...

# %%
(data.isnull().sum() / len(data) ) * 100
# Out:
# economy      0.000000
# YR2004       2.255639
# YR2005       2.255639
# YR2006       2.255639
# YR2007       1.503759
# YR2008       1.503759
# YR2009       1.127820
# YR2010       1.127820
# YR2011       1.127820
# YR2012       1.127820
# YR2013       1.127820
# YR2014       1.127820
# YR2015       1.127820
# YR2016       1.127820
# YR2017       1.127820
# YR2018       1.127820
# YR2019       1.127820
# YR2020       1.127820
# YR2021       1.127820
# YR2022       1.127820
# YR2023       1.127820
# YR2024     100.000000
# dtype: float64

# %%
data.drop('YR2024', axis = 1, inplace = True)

# %%
# Làm sạch dữ liêu: Filling missing value -> outlier processing -> Rời rạc hóa dữ liệu -> Chuẩn hóa dữ liệu

# %% [markdown]
# 1. Filling missing value:
# - interpolation
# - forward fill
# - backward fill
# - moving average
# 2. Outlier processing
# - rolling window
# - z-score trên rolling mean
# 3. Discretization
# - Phân loại theo vụ mùa, chu kỳ
# 4. Normalization
# - Chuẩn hóa theo series hoặc rolling window
